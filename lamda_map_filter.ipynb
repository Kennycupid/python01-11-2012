# %%
import math
(lambda X:math.sqrt(X))(188)
# Out:
# 13.711309200802088

# %%
name = 'Taiwo'
if name[0] == name[0].upper():
    print(True)
else:
    print(false)
# Out:
# True

# %%
(lambda password: True if (password[0]== password[0].upper()) and (password[-1]=='0') else False)(input('please enter your password:'))
# Out:
# please enter your password: Kenmane0
# True

# %%
(lambda number: 'even number' if number%2== 0  else 'odd number') (int(input('enter your number:')))
# Out:
# enter your number: 8
# 'even number'

# %%
#map
numbers = []
counter = 1
import random
while counter <=30:
    num= random.randint(25,35)
    numbers.append(num)
    counter +=1

# %%
import math
numbers_update = list(map(lambda num: math.sqrt(num), numbers))

# %%
numbers_update
# Out:
# [5.830951894845301,
#  5.830951894845301,
#  5.477225575051661,
#  5.0990195135927845,
#  5.477225575051661,
#  5.477225575051661,
#  5.916079783099616,
#  5.5677643628300215,
#  5.477225575051661,
#  5.830951894845301,
#  5.656854249492381,
#  5.291502622129181,
#  5.916079783099616,
#  5.830951894845301,
#  5.744562646538029,
#  5.5677643628300215,
#  5.385164807134504,
#  5.5677643628300215,
#  5.291502622129181,
#  5.5677643628300215,
#  5.656854249492381,
#  5.477225575051661,
#  5.477225575051661,
#  5.385164807134504,
#  5.0990195135927845,
#  5.744562646538029,
#  5.0,
#  5.291502622129181,
#  5.916079783099616,
#  5.291502622129181]

# %%
numbers_update1= list(map(lambda num: (num)**2, numbers))

# %%
numbers_update1
# Out:
# [1156,
#  1156,
#  900,
#  676,
#  900,
#  900,
#  1225,
#  961,
#  900,
#  1156,
#  1024,
#  784,
#  1225,
#  1156,
#  1089,
#  961,
#  841,
#  961,
#  784,
#  961,
#  1024,
#  900,
#  900,
#  841,
#  676,
#  1089,
#  625,
#  784,
#  1225,
#  784]

# %%
#filter
numbers_update2 = list(filter(lambda num: num <30, numbers))

# %%
numbers_update2
# Out:
# [26, 28, 29, 28, 29, 26, 25, 28, 28]

# %%
number=[]
counter = 1
import random
while counter <=200:
    num= random.randint(50,85)
    number.append(num)
    counter +=1
even_number = list(filter(lambda num: num%2== 0, number)) 
odd_number= list(filter(lambda num: num%2 == 1, number))
even_number1= list(map(lambda num: num**2, number))
odd_number1= list(map(lambda num: math.sqrt(num), number))

# %%
even_number
odd_number
even_number1
odd_number1
# Out:
# [8.366600265340756,
#  7.211102550927978,
#  7.416198487095663,
#  7.681145747868608,
#  8.54400374531753,
#  8.774964387392123,
#  9.055385138137417,
#  8.48528137423857,
#  9.055385138137417,
#  7.681145747868608,
#  8.831760866327848,
#  8.18535277187245,
#  8.831760866327848,
#  7.211102550927978,
#  8.18535277187245,
#  7.745966692414834,
#  8.94427190999916,
#  9.055385138137417,
#  9.219544457292887,
#  7.280109889280518,
#  8.12403840463596,
#  7.681145747868608,
#  7.3484692283495345,
#  9.0,
#  7.874007874011811,
#  7.416198487095663,
#  8.660254037844387,
#  8.717797887081348,
#  8.426149773176359,
#  8.306623862918075,
#  8.602325267042627,
#  8.602325267042627,
#  9.16515138991168,
#  9.0,
#  7.483314773547883,
#  8.426149773176359,
#  8.246211251235321,
#  8.246211251235321,
#  7.211102550927978,
#  9.16515138991168,
#  9.219544457292887,
#  7.745966692414834,
#  7.681145747868608,
#  7.874007874011811,
#  9.219544457292887,
#  9.0,
#  9.0,
#  7.54983443527075,
# ...
